# %%
import pandas as pd

# %%
df = pd.read_csv('../data/ratings.csv')
print(df.shape)
df.head(5)
# Out:
# (5976479, 3)
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
# df_exuser = pd.read_csv('../data/exclude_users_data.csv')
# print(df_exuser.shape)
# df_exuser.head(5)

# %%
# df.loc[df['user_id'] == 9256] # try to find excluded user in original ratings

# %%
# df_cleaned = df.set_index('user_id')
# df_cleaned.head()

# %%
# df_cleaned = df_cleaned.drop(df_cleaned.index[df_exuser['user_id']])
# print(df_cleaned.shape)

# %%
# df_cleaned['user_id'] = df_cleaned.index
# df_cleaned.head()

# %%
df_exbook = pd.read_csv('../data/exclude_books.csv')
print(df_exbook.shape)
df_exbook.head(5)
# Out:
# (4236, 1)
#    book_id
# 0       45
# 1       48
# 2       61
# 3       84
# 4      123

# %%
df_cleaned2 = df.set_index('book_id')
df_cleaned2.head()
# Out:
#          user_id  rating
# book_id
# 258            1       5
# 4081           2       4
# 260            2       5
# 9296           2       5
# 2318           2       3

# %%
df_cleaned2 = df_cleaned2.drop(df_cleaned2.index[df_exbook['book_id']])
print(df_cleaned2.shape)
df_cleaned2
# Out:
# (3421894, 2)
#          user_id  rating
# book_id
# 9296           2       5
# 2318           2       3
# 2686           2       5
# 8519           2       5
# 964            4       4
# 6351           6       4
# 1237           4       5
# 222            4       4
# 5556           1       3
# 1296           4       3
# 596            4       3
# 397            9       3
# 4815           9       5
# 1221           9       3
# 1301           9       2
# 1986           9       2
# 963            9       2
# 596            9       2
# 7868           9       2
# 1407           9       2
# 2559          11       5
# 6944          11       3
# 3560          11       5
# 2903          15       4
# 167           15       5
# 465           15       4
# 8440          15       4
# 4043          15       4
# 9363          15       4
# 8842          15       3
# ...          ...     ...
# 3510       49802       4
# 3832       49802       4
# 3874       49802       5
# 3990       49802       3
# ...

# %%
df_cleaned2 = df_cleaned2.reset_index()
df_cleaned2.head()
# Out:
#    book_id  user_id  rating
# 0     9296        2       5
# 1     2318        2       3
# 2     2686        2       5
# 3     8519        2       5
# 4      964        4       4

# %%
df_cleaned2 = df_cleaned2.set_index('user_id')
df_cleaned2.head()
# Out:
#          book_id  rating
# user_id
# 2           9296       5
# 2           2318       3
# 2           2686       5
# 2           8519       5
# 4            964       4

# %%
df_cleaned2 = df_cleaned2.sort_index()
df_cleaned2
# Out:
#          book_id  rating
# user_id
# 1            437       4
# 1            143       5
# 1            421       5
# 1           3294       5
# 1            262       3
# 1           1030       4
# 1            414       4
# 1           1310       4
# 1            869       4
# 1            140       3
# 1            216       3
# 1             98       3
# 1            329       4
# 1            256       3
# 1             16       3
# 1             31       4
# 1             67       3
# 1           1761       4
# 1           1942       3
# 1            128       5
# 1           1011       4
# 1           2133       5
# 1           1180       4
# 1           4893       3
# 1            231       3
# 1            642       4
# 1           2535       5
# 1           2063       4
# 1           3889       3
# 1           1644       5
# ...          ...     ...
# 53424       8609       4
# 53424        446       5
# 53424       3344       4
# 53424       3077       4
# ...

# %%
df_cleaned2 = df_cleaned2.reset_index()
df_cleaned2.head()
# Out:
#    user_id  book_id  rating
# 0        1      437       4
# 1        1      143       5
# 2        1      421       5
# 3        1     3294       5
# 4        1      262       3

# %%
df_cleaned2.to_csv('../data/cleaned_ratings.csv')
