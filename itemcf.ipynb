# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
from surprise import Dataset, KNNBasic, evaluate, Reader, NormalPredictor
from surprise.model_selection import cross_validate, train_test_split

# %%
# df_to_read = pd.read_csv('data/to_read.csv')
# df_tag_names = pd.read_csv('data/tags.csv')
# df_tags = pd.read_csv('data/book_tags.csv')
df_books = pd.read_csv('data/books.csv', usecols=['book_id', 'original_title'])
df = pd.read_csv('data/ratings.csv')
df_books.set_index('book_id', inplace=True)
df_books.head(5)
# Out:
#                                    original_title
# book_id
# 1                                The Hunger Games
# 2        Harry Potter and the Philosopher's Stone
# 3                                        Twilight
# 4                           To Kill a Mockingbird
# 5                                The Great Gatsby

# %%
# use a smaller sample df
small_df = df.sample(100)
small_df.head(5)
# Out:
#          user_id  book_id  rating
# 2031298    27679       28       4
# 3082584    27497     2478       4
# 4967515    17467     9876       5
# 3550726    41481     2761       4
# 1065075    16308      354       5

# %%
reader = Reader(rating_scale=(1,5)) # rating scale 1 to 5
data = Dataset.load_from_df(small_df[['user_id', 'book_id', 'rating']], reader) #user id, item id and ratings (in that order)

# %%
sim_options = {'name': 'cosine', 'user-based': False}
knn = KNNBasic(sim_options=sim_options)

# %%
# cross_validate(knn, data, cv=5, verbose=True)

# %%
# trainingSet = data.build_full_trainset()
trainingSet, testset = train_test_split(data, test_size=.25)

# %%
knn.fit(trainingSet)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
knn.predict(21294, 34, 3) # predict example
# Out:
# Prediction(uid=21294, iid=34, r_ui=3, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'})

# %%
#trainset, testset = train_test_split(data, test_size=.25) # 25% is test set
#knn.fit(trainset)

# %%
# testSet = trainingSet.build_anti_testset()
predictions = knn.test(testSet)

# %%
predictions
# Out:
# [Prediction(uid='196', iid='302', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='377', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='51', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='346', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='474', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='265', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='465', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='451', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='86', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1014', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='222', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='40', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='29', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='785', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='387', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='274', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1042', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1184', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='392', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='486', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='144', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='118', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='546', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='95', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='768', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='277', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='234', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='246', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='98', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='193', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='88', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='194', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1081', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='603', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='796', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='32', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='16', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='304', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='979', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='564', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='327', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='201', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1137', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='241', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='4', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='332', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='100', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='432', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='322', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='181', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='196', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='679', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='384', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='143', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='423', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='515', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='20', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='288', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='219', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='526', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='919', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='26', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='232', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='427', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='512', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='15', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1049', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='416', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='165', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='690', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='248', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1444', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='5', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='229', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='237', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='480', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='54', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='366', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='518', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='403', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='625', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='338', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1016', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='154', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='275', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1153', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='498', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='209', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='23', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='294', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='208', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='685', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='328', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='496', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='132', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='174', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='96', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='151', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='307', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='648', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='21', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='832', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='514', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='789', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='485', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='317', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='195', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='200', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='385', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='750', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='264', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='245', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='135', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1147', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='471', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='658', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='140', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='379', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='815', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='479', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='368', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1211', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1134', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='836', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='272', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='756', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='787', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='14', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='955', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='419', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='405', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='504', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='466', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='268', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='117', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='273', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='559', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='794', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='323', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='177', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='231', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='2', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='137', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1336', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='164', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='281', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1240', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='298', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='443', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1035', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='79', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='258', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='455', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='755', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='673', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='172', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1217', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='719', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1267', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='930', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='216', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1079', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='452', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='61', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='48', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='360', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='77', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='476', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='483', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='748', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='220', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='255', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='280', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='408', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='235', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='228', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1098', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='347', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='178', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='478', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='688', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='10', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='127', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='106', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='69', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='944', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='790', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1091', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='214', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1028', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='554', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='109', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='171', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='318', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='568', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='842', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='65', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='591', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='401', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='339', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='746', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='68', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='7', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1018', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='218', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='623', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='334', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='344', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='145', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='56', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='89', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='141', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='576', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='133', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='813', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='872', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='146', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='507', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='367', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='468', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='595', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='11', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='520', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='82', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='501', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='3', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='695', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='198', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='189', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='767', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='705', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='64', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='357', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='484', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='508', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='303', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='215', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='749', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='829', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='204', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1295', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='33', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='160', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='321', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='343', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='227', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='191', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='903', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='183', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='724', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='430', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1197', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='134', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='751', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='212', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='256', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='662', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='984', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1067', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='410', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='879', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='271', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1086', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='649', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='951', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='197', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='678', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='199', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='709', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='169', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='597', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1393', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='333', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1115', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='577', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='378', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='425', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='959', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1224', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1017', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='175', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='558', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='206', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='402', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='640', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='522', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='62', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='12', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='291', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='462', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='612', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='758', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='163', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1451', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='250', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='823', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='186', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='731', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='71', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='781', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='176', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1181', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='78', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='436', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='631', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='716', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='188', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='699', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='604', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='97', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='460', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='715', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='17', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='315', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='505', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='279', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='80', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='60', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='325', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='407', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='531', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='587', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='892', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1047', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='47', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
# ...
#  Prediction(uid='196', iid='1025', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1364', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='266', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='727', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='828', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='548', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1132', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='993', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='136', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='996', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='562', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='653', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='74', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1493', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='45', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='867', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='876', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='158', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1183', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='500', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='610', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='887', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1299', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='918', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='41', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1066', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='336', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1117', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1169', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1262', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='348', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='270', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1053', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1464', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='374', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='621', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='607', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1030', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='777', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='700', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='297', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='925', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='928', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='394', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='549', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='999', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1471', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='341', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1009', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='391', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='467', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='811', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='805', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='519', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1036', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='84', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='894', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='574', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1113', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1306', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='638', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1314', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1131', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1069', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1084', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1407', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='878', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1242', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='359', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='579', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='884', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='691', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='954', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='261', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1112', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1090', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='445', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='635', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1135', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='76', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1082', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1215', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1328', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1013', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1170', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1265', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='735', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='352', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='833', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='722', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='434', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='801', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='224', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='358', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='966', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1351', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='675', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='991', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='633', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1102', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1424', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1163', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='1413', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='830', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='924', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='976', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='825', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='196', iid='389', r_ui=3.52986, est=4.053333333333334, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  ...]

# %%
# get top 3 recommendations
from collections import defaultdict

def get_top_rec(predictions, top=3):
    for uid, iid, r, est, _ in predictions:
        top_recs[uid].append((iid, est))
    for uid, user_ratings in top_recs.items():
        user_ratings.sort(key = lambda x: x[1], reverse = True)
        top_recs[uid] = user_ratings[:topN]
        
    return top_recs

# %%
top_rec = get_top_rec(predictions)

# %%
def get_book_name():
    
    return name
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3
# 5        2       26       4
# 6        2      315       3
# 7        2       33       4
# 8        2      301       5
# 9        2     2686       5

# %%
for uid, user_ratings in top_rec.items():
    print(uid, [rid_to_name[iid] for (iid, _) in user_ratings])

# %%
# Out:
# 53424

# %%
# Out:
# 10000

# %%
# Out:
# 5976479

# %%
# Out:
# (5976479, 3)
